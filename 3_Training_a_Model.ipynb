# %% [markdown]
# # Plagiarism Detection Model
#
# Now that you've created training and test data, you are ready to define and train a model. Your goal in this notebook, will be to train a binary classification model that learns to label an answer file as either plagiarized or not, based on the features you provide the model.
#
# This task will be broken down into a few discrete steps:
#
# * Upload your data to S3.
# * Define a binary classification model and a training script.
# * Train your model and deploy it.
# * Evaluate your deployed classifier and answer some questions about your approach.
#
# To complete this notebook, you'll have to complete all given exercises and answer all the questions in this notebook.
# > All your tasks will be clearly labeled **EXERCISE** and questions as **QUESTION**.
#
# It will be up to you to explore different classification models and decide on a model that gives you the best performance for this dataset.
#
# ---

# %% [markdown]
# ## Load Data to S3
#
# In the last notebook, you should have created two files: a `training.csv` and `test.csv` file with the features and class labels for the given corpus of plagiarized/non-plagiarized text data.
#
# >The below cells load in some AWS SageMaker libraries and creates a default bucket. After creating this bucket, you can upload your locally stored data to S3.
#
# Save your train and test `.csv` feature files, locally. To do this you can run the second notebook "2_Plagiarism_Feature_Engineering" in SageMaker or you can manually upload your files to this notebook using the upload icon in Jupyter Lab. Then you can upload local files to S3 by using `sagemaker_session.upload_data` and pointing directly to where the training data is saved.

# %%
import pandas as pd
import boto3
import sagemaker

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# session and role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# create an S3 bucket
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## EXERCISE: Upload your training data to S3
#
# Specify the `data_dir` where you've saved your `train.csv` file. Decide on a descriptive `prefix` that defines where your data will be uploaded in the default S3 bucket. Finally, create a pointer to your training data by calling `sagemaker_session.upload_data` and passing in the required parameters. It may help to look at the [Session documentation](https://sagemaker.readthedocs.io/en/stable/session.html#sagemaker.session.Session.upload_data) or previous SageMaker code examples.
#
# You are expected to upload your entire directory. Later, the training script will only access the `train.csv` file.

# %%
# should be the name of directory you created to save your features data
data_dir = 'plagiarism_data'

# set prefix, a descriptive name for a directory  
prefix = 'mime_project'

# upload all data to S3
input_data = sagemaker_session.upload_data(path=data_dir, bucket=bucket, key_prefix=prefix)
print(input_data)
# Out:
# s3://sagemaker-us-east-1-086714687135/mime_project

# %% [markdown]
# ### Test cell
#
# Test that your data has been successfully uploaded. The below cell prints out the items in your S3 bucket and will throw an error if it is empty. You should see the contents of your `data_dir` and perhaps some checkpoints. If you see any other files listed, then you may have some old model files that you can delete via the S3 console (though, additional files shouldn't affect the performance of model developed in this notebook).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# confirm that data is in S3 bucket
empty_check = []
for obj in boto3.resource('s3').Bucket(bucket).objects.all():
    empty_check.append(obj.key)
    print(obj.key)

assert len(empty_check) !=0, 'S3 bucket is empty.'
print('Test passed!')
# Out:
# boston-xgboost-HL/output/xgboost-2021-04-27-01-57-06-763/output/model.tar.gz
# boston-xgboost-HL/test.csv
# boston-xgboost-HL/train.csv
# boston-xgboost-HL/validation.csv
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-001-aefc31f2/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-002-9ef82165/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-003-b85bc827/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-004-a44eba14/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-005-5b5f0254/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-006-93c79ad8/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-007-f699621e/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-008-76fc5476/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-009-b291f4a7/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-010-9761962a/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-011-eb559d7f/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-012-26d01835/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-013-4356ffd0/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-014-94aef421/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-015-8043fbd2/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-016-1c0972a3/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-017-d0b122b8/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-018-89304c54/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-019-ada421f0/output/model.tar.gz
# boston-xgboost-tuning-HL/output/xgboost-210503-0222-020-fe7847fe/output/model.tar.gz
# boston-xgboost-tuning-HL/test.csv
# boston-xgboost-tuning-HL/train.csv
# boston-xgboost-tuning-HL/validation.csv
# counties/kmeans-2021-05-10-01-36-46-934/output/model.tar.gz
# counties/kmeans-2021-05-10-01-36-46-934/profiler-output/framework/training_job_end.ts
# counties/kmeans-2021-05-10-01-36-46-934/profiler-output/system/incremental/2021051001/1620610800.algo-1.json
# counties/kmeans-2021-05-10-01-36-46-934/profiler-output/system/training_job_end.ts
# counties/kmeans-2021-05-11-00-49-45-993/output/model.tar.gz
# counties/kmeans-2021-05-11-00-49-45-993/profiler-output/framework/training_job_end.ts
# counties/kmeans-2021-05-11-00-49-45-993/profiler-output/system/incremental/2021051100/1620694320.algo-1.json
# counties/kmeans-2021-05-11-00-49-45-993/profiler-output/system/incremental/2021051100/1620694380.algo-1.json
# counties/kmeans-2021-05-11-00-49-45-993/profiler-output/system/training_job_end.ts
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-report.html
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-report.ipynb
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/BatchSize.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/CPUBottleneck.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/Dataloader.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/IOBottleneck.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/LoadBalancing.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/kmeans-2021-05-11-00-49-45-993/rule-output/ProfilerReport-1620694185/profiler-output/profiler-reports/StepOutlier.json
# counties/pca-2021-05-09-04-39-53-421/output/model.tar.gz
# counties/pca-2021-05-09-04-39-53-421/profiler-output/framework/training_job_end.ts
# counties/pca-2021-05-09-04-39-53-421/profiler-output/system/incremental/2021050904/1620535320.algo-1.json
# counties/pca-2021-05-09-04-39-53-421/profiler-output/system/incremental/2021050904/1620535380.algo-1.json
# counties/pca-2021-05-09-04-39-53-421/profiler-output/system/training_job_end.ts
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-report.html
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-report.ipynb
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/BatchSize.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/CPUBottleneck.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/Dataloader.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/IOBottleneck.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/LoadBalancing.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/pca-2021-05-09-04-39-53-421/rule-output/ProfilerReport-1620535193/profiler-output/profiler-reports/StepOutlier.json
# counties/pca-2021-05-10-01-15-13-942/output/model.tar.gz
# counties/pca-2021-05-10-01-15-13-942/profiler-output/framework/training_job_end.ts
# counties/pca-2021-05-10-01-15-13-942/profiler-output/system/incremental/2021051001/1620609480.algo-1.json
# counties/pca-2021-05-10-01-15-13-942/profiler-output/system/incremental/2021051001/1620609540.algo-1.json
# counties/pca-2021-05-10-01-15-13-942/profiler-output/system/training_job_end.ts
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-report.html
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-report.ipynb
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/BatchSize.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/CPUBottleneck.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/Dataloader.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/GPUMemoryIncrease.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/IOBottleneck.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/LoadBalancing.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/LowGPUUtilization.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/MaxInitializationTime.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/OverallSystemUsage.json
# counties/pca-2021-05-10-01-15-13-942/rule-output/ProfilerReport-1620609313/profiler-output/profiler-reports/StepOutlier.json
# counties/pca-2021-05-11-00-35-41-834/output/model.tar.gz
# counties/pca-2021-05-11-00-35-41-834/profiler-output/framework/training_job_end.ts
# counties/pca-2021-05-11-00-35-41-834/profiler-output/system/incremental/2021051100/1620693480.algo-1.json
# counties/pca-2021-05-11-00-35-41-834/profiler-output/system/incremental/2021051100/1620693540.algo-1.json
# counties/pca-2021-05-11-00-35-41-834/profiler-output/system/training_job_end.ts
# counties/pca-2021-05-11-00-35-41-834/rule-output/ProfilerReport-1620693341/profiler-output/profiler-report.html
# counties/pca-2021-05-11-00-35-41-834/rule-output/ProfilerReport-1620693341/profiler-output/profiler-report.ipynb
# counties/pca-2021
json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/GPUMemoryIncrease.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/IOBottleneck.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/LoadBalancing.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/LowGPUUtilization.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/MaxInitializationTime.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/OverallSystemUsage.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-25-01-436/rule-output/ProfilerReport-1621387501/profiler-output/profiler-reports/StepOutlier.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/debug-output/collections/000000000/worker_0_collections.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/output/model.tar.gz
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/profiler-output/system/incremental/2021051901/1621388160.algo-1.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/profiler-output/system/incremental/2021051901/1621388220.algo-1.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-report.html
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-report.ipynb
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/BatchSize.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/CPUBottleneck.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/Dataloader.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/GPUMemoryIncrease.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/IOBottleneck.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/LoadBalancing.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/LowGPUUtilization.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/MaxInitializationTime.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/OverallSystemUsage.json
# sagemaker/moon-data/pytorch-training-2021-05-19-01-33-43-870/rule-output/ProfilerReport-1621388023/profiler-output/profiler-reports/StepOutlier.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/debug-output/claim.smd
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/debug-output/collections/000000000/worker_0_collections.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/output/model.tar.gz
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/profiler-output/system/incremental/2021052001/1621473360.algo-1.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/profiler-output/system/incremental/2021052001/1621473420.algo-1.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-report.html
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-report.ipynb
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/BatchSize.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/CPUBottleneck.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/Dataloader.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/GPUMemoryIncrease.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/IOBottleneck.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/LoadBalancing.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/LowGPUUtilization.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/MaxInitializationTime.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/OverallSystemUsage.json
# sagemaker/moon-data/pytorch-training-2021-05-20-01-13-54-051/rule-output/ProfilerReport-1621473234/profiler-output/profiler-reports/StepOutlier.json
# sagemaker/moon-data/train.csv
# sagemaker/sentiment_rnn/train.csv
# sagemaker/sentiment_rnn/word_dict.pkl
# sentiment-update/new_data.csv
# sentiment-update/new_train.csv
# sentiment-update/new_validation.csv
# sentiment-update/output/xgboost-2021-05-03-05-52-04-065/output/model.tar.gz
# sentiment-update/test.csv
# sentiment-update/train.csv
# sentiment-update/validation.csv
# sentiment-web-app/output/xgboost-2021-05-02-06-50-07-664/output/model.tar.gz
# sentiment-web-app/test.csv
# sentiment-web-app/train.csv
# sentiment-web-app/validation.csv
# sentiment-xgboost/output/xgboost-2021-05-02-02-22-19-585/output/model.tar.gz
# sentiment-xgboost/output/xgboost-210503-0343-001-ad56342f/output/model.tar.gz
# sentiment-xgboost/output/xgboost-210503-0343-002-e823c0c2/output/model.tar.gz
# sentiment-xgboost/output/xgboost-210503-0343-003-16bc5721/output/model.tar.gz
# sentiment-xgboost/output/xgboost-210503-0343-004-6bb0cd84/output/model.tar.gz
# sentiment-xgboost/output/xgboost-210503-0343-005-09f9e8ce/output/model.tar.gz
# sentiment-xgboost/output/xgboost-210503-0343-006-4a0999c3/output/model.tar.gz
# sentiment-xgboost/test.csv
# sentiment-xgboost/train.csv
# sentiment-xgboost/validation.csv
# xgboost-2021-05-02-02-29-15-378/test.csv.out
# xgboost-2021-05-02-07-01-47-919/test.csv.out
# xgboost-2021-05-03-06-01-04-157/test.csv.out
# xgboost-2021-05-04-01-24-06-900/new_data.csv.out
# xgboost-210503-0222-017-d0b122b8-2021-05-03-03-01-00-137/test.csv.out
# Test passed!

# %% [markdown]
# ---
#
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# The type of model you create is up to you. For a binary classification task, you can choose to go one of three routes:
# * Use a built-in classification algorithm, like LinearLearner.
# * Define a custom Scikit-learn classifier, a comparison of models can be found [here](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html).
# * Define a custom PyTorch neural network classifier.
#
# It will be up to you to test out a variety of models and choose the best one. Your project will be graded on the accuracy of your final model.
#
# ---
#
# ## EXERCISE: Complete a training script
#
# To implement a custom classifier, you'll need to complete a `train.py` script. You've been given the folders `source_sklearn` and `source_pytorch` which hold starting code for a custom Scikit-learn model and a PyTorch model, respectively. Each directory has a `train.py` training script. To complete this project **you only need to complete one of these scripts**; the script that is responsible for training your final model.
#
# A typical training script:
# * Loads training data from a specified directory
# * Parses any training & model hyperparameters (ex. nodes in a neural network, training epochs, etc.)
# * Instantiates a model of your design, with any specified hyperparams
# * Trains that model
# * Finally, saves the model so that it can be hosted/deployed, later
#
# ### Defining and training a model
# Much of the training script code is provided for you. Almost all of your work will be done in the `if __name__ == '__main__':` section. To complete a `train.py` file, you will:
# 1. Import any extra libraries you need
# 2. Define any additional model training hyperparameters using `parser.add_argument`
# 2. Define a model in the `if __name__ == '__main__':` section
# 3. Train the model in that same section
#
# Below, you can use `!pygmentize` to display an existing `train.py` file. Read through the code; all of your tasks are marked with `TODO` comments.
#
# **Note: If you choose to create a custom PyTorch model, you will be responsible for defining the model in the `model.py` file,** and a `predict.py` file is provided. If you choose to use Scikit-learn, you only need a `train.py` file; you may import a classifier from the `sklearn` library.

# %%
# directory can be changed to: source_sklearn or source_pytorch
# !pygmentize source_sklearn/train.py
# Out:
# from __future__ import print_function
# from sklearn.ensemble import RandomForestClassifier
# import argparse
# import os
# import pandas as pd
#
# # sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23.
# # from sklearn.externals import joblib
# # Import joblib package directly
# import joblib
#
# ## TODO: Import any additional libraries you need to define a model
#
#
# # Provided model load function
# def model_fn(model_dir):
#     """Load model from the model_dir. This is the same model that is saved
#     in the main if statement.
#     """
#     print("Loading model.")
#
#     # load using joblib
#     model = joblib.load(os.path.join(model_dir, "model.joblib"))
#     print("Done loading model.")
#
#     return model
#
#
# ## TODO: Complete the main code
# if __name__ == '__main__':
#
#     # All of the model parameters and training parameters are sent as arguments
#     # when this script is executed, during a training job
#
#     # Here we set up an argument parser to easily access the parameters
#     parser = argparse.ArgumentParser()
#
#     # SageMaker parameters, like the directories for training data and saving models; set automatically
#     # Do not need to change
#     parser.add_argument('--output-data-dir', type=str, default=os.environ['SM_OUTPUT_DATA_DIR'])
#     parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--data-dir', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
#
#     ## TODO: Add any additional arguments that you will need to pass into your model
#     parser.add_argument('--n_estimators', type=int, default=100, metavar='NE',
#                         help='number of estimators (default: 100)')
#     parser.add_argument('--criterion', type=int, default='gini', metavar='C',
#                         help='function to measure the quality of a split  (default: gini)')
#     parser.add_argument('--max_depth', type=str, default=2, metavar='MD',
#                         help='maximum depth of the tree (default: 2)')
#
#     # args holds all passed-in arguments
#     args = parser.parse_args()
#
#     # Read in csv training file
#     training_dir = args.data_dir
#     train_data = pd.read_csv(os.path.join(training_dir, "train.csv"), header=None, names=None)
#
#     # Labels are in the first column
#     train_y = train_data.iloc[:,0]
#     train_x = train_data.iloc[:,1:]
#
#
#     ## --- Your code here --- ##
#
#
#     ## TODO: Define a model
#     model = RandomForestClassifier(args.n_estimators, args.criterion, args.max_depth) #.to(device)
#
#
#     ## TODO: Train the model
#     model.fit(train_x, train_y)
#
#
#     ## --- End of your code  --- ##
#
#
#     # Save the trained model
#     joblib.dump(model, os.path.join(args.model_dir, "model.joblib"))

# %% [markdown]
# ### Provided code
#
# If you read the code above, you can see that the starter code includes a few things:
# * Model loading (`model_fn`) and saving code
# * Getting SageMaker's default hyperparameters
# * Loading the training data by name, `train.csv` and extracting the features and labels, `train_x`, and `train_y`
#
# If you'd like to read more about model saving with [joblib for sklearn](https://scikit-learn.org/stable/modules/model_persistence.html) or with [torch.save](https://pytorch.org/tutorials/beginner/saving_loading_models.html), click on the provided links.

# %% [markdown]
# ---
# # Create an Estimator
#
# When a custom model is constructed in SageMaker, an entry point must be specified. This is the Python file which will be executed when the model is trained; the `train.py` function you specified above. To run a custom training script in SageMaker, construct an estimator, and fill in the appropriate constructor arguments:
#
# * **entry_point**: The path to the Python script SageMaker runs for training and prediction.
# * **source_dir**: The path to the training script directory `source_sklearn` OR `source_pytorch`.
# * **role**: Role ARN, which was specified, above.
# * **train_instance_count**: The number of training instances (should be left at 1).
# * **train_instance_type**: The type of SageMaker instance for training. Note: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * **sagemaker_session**: The session used to train on Sagemaker.
# * **hyperparameters** (optional): A dictionary `{'name':value, ..}` passed to the train function as hyperparameters.
#
# Note: For a PyTorch model, there is another optional argument **framework_version**, which you can set to the latest version of PyTorch, `1.0`.
#
# ## EXERCISE: Define a Scikit-learn or PyTorch estimator
#
# To import your desired estimator, use one of the following lines:
# ```
# from sagemaker.sklearn.estimator import SKLearn
# ```
# ```
# from sagemaker.pytorch import PyTorch
# ```

# %%
# your import and estimator code, here
from sagemaker.sklearn.estimator import SKLearn

output_path = 's3://{}/{}'.format(bucket, prefix)

# instantiate a pytorch estimator
estimator = SKLearn(entry_point='train.py',
                    source_dir='source_sklearn', # this should be just "source" for your code
                    role=role,
                    framework_version='0.20.0',
                    py_version = 'py3',
                    instance_count=1,
                    instance_type='ml.c4.xlarge',
                    output_path=output_path,
                    sagemaker_session=sagemaker_session,
                    hyperparameters={'n_estimators': 105, 'criterion': 'gini', 'max_depth': 3})

# %% [markdown]
# ## EXERCISE: Train the estimator
#
# Train your estimator on the training data stored in S3. This should create a training job that you can monitor in your SageMaker console.

# %%
# %%time

# Train your estimator on S3 training data
estimator.fit({'train': input_data})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     675
#     676         """
# --> 677         self._prepare_for_training(job_name=job_name)
#     678
#     679         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in _prepare_for_training(self, job_name)
#    2232             self.code_uri = self.uploaded_code.s3_prefix
#    2233         else:
# -> 2234             self.uploaded_code = self._stage_user_code_in_s3()
#    2235             code_dir = self.uploaded_code.s3_prefix
#    2236             script = self.uploaded_code.script_name
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/estimator.py in _stage_user_code_in_s3(self)
#    2302             dependencies=self.dependencies,
#    2303             kms_key=kms_key,
# -> 2304             s3_resource=self.sagemaker_session.s3_resource,
#    2305         )
#    2306
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sagemaker/fw_utils.py in tar_and_upload_dir(session, bucket, s3_key_prefix, script, directory, dependencies, kms_key, s3_resource)
#     232     try:
#     233         source_files = _list_files_to_compress(script, directory) + dependencies
# --> 234         tar_file = sagemaker.utils.create_tar_file(
#     235             source_files, os.path.join(tmp, _TAR_SOURCE_FILENAME)
#     236         )
#
# AttributeError: module 'sagemaker' has no attribute 'utils'

# %% [markdown]
# ## EXERCISE: Deploy the trained model
#
# After training, deploy your model to create a `predictor`. If you're using a PyTorch model, you'll need to create a trained `PyTorchModel` that accepts the trained `<model>.model_data` as an input parameter and points to the provided `source_pytorch/predict.py` file as an entry point.
#
# To deploy a trained model, you'll use `<model>.deploy`, which takes in two arguments:
# * **initial_instance_count**: The number of deployed instances (1).
# * **instance_type**: The type of SageMaker instance for deployment.
#
# Note: If you run into an instance error, it may be because you chose the wrong training or deployment instance_type. It may help to refer to your previous exercise code to see which types of instances we used.

# %%
# %%time

# uncomment, if needed
# from sagemaker.pytorch import PyTorchModel


# deploy your model to create a predictor
predictor = None

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to our test data.
#
# The provided cell below, reads in the test data, assuming it is stored locally in `data_dir` and named `test.csv`. The labels and features are extracted from the `.csv` file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
import os

# read in test data, assuming it is stored locally
test_data = pd.read_csv(os.path.join(data_dir, "test.csv"), header=None, names=None)

# labels are in the first column
test_y = test_data.iloc[:,0]
test_x = test_data.iloc[:,1:]

# %% [markdown]
# ## EXERCISE: Determine the accuracy of your model
#
# Use your deployed `predictor` to generate predicted, class labels for the test data. Compare those to the *true* labels, `test_y`, and calculate the accuracy as a value between 0 and 1.0 that indicates the fraction of test data that your model classified correctly. You may use [sklearn.metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) for this calculation.
#
# **To pass this project, your model should get at least 90% test accuracy.**

# %%
# First: generate predicted, class labels
test_y_preds = None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# test that your model generates the correct number of labels
assert len(test_y_preds)==len(test_y), 'Unexpected number of predictions.'
print('Test passed!')

# %%
# Second: calculate the test accuracy
accuracy = None

print(accuracy)


## print out the array of predicted and true labels, if you want
print('\nPredicted class labels: ')
print(test_y_preds)
print('\nTrue class labels: ')
print(test_y.values)

# %% [markdown]
# ### Question 1: How many false positives and false negatives did your model produce, if any? And why do you think this is?

# %% [markdown]
# ** Answer**:

# %% [markdown]
# ### Question 2: How did you decide on the type of model to use?

# %% [markdown]
# ** Answer**:

# %% [markdown]
# ----
# ## EXERCISE: Clean up Resources
#
# After you're done evaluating your model, **delete your model endpoint**. You can do this with a call to `.delete_endpoint()`. You need to show, in this notebook, that the endpoint was deleted. Any other resources, you may delete from the AWS console, and you will find more instructions on cleaning up all your resources, below.

# %%
# uncomment and fill in the line below!
# <name_of_deployed_predictor>.delete_endpoint()

# %% [markdown]
# ### Deleting S3 bucket
#
# When you are *completely* done with training and testing models, you can also delete your entire S3 bucket. If you do this before you are done training your model, you'll have to recreate your S3 bucket and upload your training data again.

# %%
# deleting bucket, uncomment lines below

# bucket_to_delete = boto3.resource('s3').Bucket(bucket)
# bucket_to_delete.objects.all().delete()

# %% [markdown]
# ### Deleting all your models and instances
#
# When you are _completely_ done with this project and do **not** ever want to revisit this notebook, you can choose to delete all of your SageMaker notebook instances and models by following [these instructions](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html). Before you delete this notebook instance, I recommend at least downloading a copy and saving it, locally.

# %% [markdown]
# ---
# ## Further Directions
#
# There are many ways to improve or add on to this project to expand your learning or make this more of a unique project for you. A few ideas are listed below:
# * Train a classifier to predict the *category* (1-3) of plagiarism and not just plagiarized (1) or not (0).
# * Utilize a different and larger dataset to see if this model can be extended to other types of plagiarism.
# * Use language or character-level analysis to find different (and more) similarity features.
# * Write a complete pipeline function that accepts a source text and submitted text file, and classifies the submitted text as plagiarized or not.
# * Use API Gateway and a lambda function to deploy your model to a web application.
#
# These are all just options for extending your work. If you've completed all the exercises in this notebook, you've completed a real-world application, and can proceed to submit your project. Great job!
